# %% [raw]
# ---
# title: "Bureau of Really Large Data Analysis Leaks"
# format: html
# date: today
# author: "David Gasquez"
# ---

# %% [markdown]
# Let's start by loading the data.

# %%
import pandas as pd

employees_df = pd.read_csv("../data/employees.csv")
safehouses_df = pd.read_csv("../data/safehouses.csv")
divisions_df = pd.read_csv("../data/divisions.csv")
managers_df = pd.read_csv("../data/managers.csv")
actions_df = pd.read_csv("../data/actions.csv")

# %% [markdown]
# ## Employees

# %%
employees_df.sample(5)
# Out:
#        EmployeeID          EmployeeName                   JobTitle  \
# 512           513  Christopher Mckinney             Data Scientist
# 24693       24698        Andrew Fleming  Machine Learning Engineer
# 6804         6807           Omar Chavez               Data Analyst
# 12078       12081         Timothy Cohen           Business Analyst
# 7650         7653          Austin Blair              Data Engineer
#
#                                 Email                   Phone  \
# 512    christopher_mckinney@brlda.gov  \t+1-212-758-3594x7701
# 24693        andrew_fleming@brlda.gov           (083)562-9918
# 6804            omar_chavez@brlda.gov            079.884.2902
# 12078         timothy_cohen@brlda.gov  \t+1-606-026-0666x1798
# 7650           austin_blair@brlda.gov            865.692.3918
#
#                        Manager
# 512    Mrs. Michelle James DDS
# 24693           Matthew Joseph
# 6804        Mrs. Lynn Owens MD
# 12078          Ashley Marshall
# 7650           Lee Herrera DVM

# %%
employees_df["EmployeeName"].value_counts().head(5)
# Out:
# EmployeeName
# Michael Smith       12
# David Smith         12
# Lisa Smith          11
# John Smith          11
# Michael Williams    10
# Name: count, dtype: int64

# %% [markdown]
# Some duplicate employees are present in the data...

# %%
employees_df[employees_df["EmployeeName"] == "Michael Smith"]
# Out:
#        EmployeeID   EmployeeName                   JobTitle  \
# 4448         4451  Michael Smith            Project Manager
# 5129         5132  Michael Smith               Scrum Master
# 7455         7458  Michael Smith  Quality Assurance Analyst
# 10672       10675  Michael Smith             Data Scientist
# 11683       11686  Michael Smith  Quality Assurance Analyst
# 13957       13960  Michael Smith            Program Manager
# 15668       15672  Michael Smith               Scrum Master
# 17442       17446  Michael Smith               Data Analyst
# 17570       17574  Michael Smith            Program Manager
# 19322       19326  Michael Smith  Machine Learning Engineer
# 22603       22608  Michael Smith            Program Manager
# 23884       23889  Michael Smith            Project Manager
#
#                          Email                    Phone           Manager
# 4448   michael_smith@brlda.gov   001-137-479-2502x05426     Nathan Guerra
# 5129   michael_smith@brlda.gov        223-274-6121x5268     David Houston
# 7455   michael_smith@brlda.gov        (202)737-6861x908       Pamela Hale
# 10672  michael_smith@brlda.gov     001-192-379-3454x580       Sarah Brown
# 11683  michael_smith@brlda.gov     001-038-692-4506x839      Patrick Cruz
# 13957  michael_smith@brlda.gov       (471)896-2210x7208  Heather Crawford
# 15668  michael_smith@brlda.gov       668.014.9966x33380     Gregory Floyd
# 17442  michael_smith@brlda.gov  \t+1-544-294-4533x69316   Richard Collins
# 17570  michael_smith@brlda.gov               9730334254    Michele Graham
# 19322  michael_smith@brlda.gov             081-057-7739      Joshua James
# 22603  michael_smith@brlda.gov    001-714-897-8059x3979      Amber Garcia
# 23884  michael_smith@brlda.gov        \t+1-800-158-9222    Michael Harris

# %% [markdown]
# Are they all the same employee? The email match but the ID and Phone don't.
#
# Let's focus on the missing data. If they removed their users, we should see some missing EmployeeID values.

# %%
# Check min and max EmployeeID
min_eid = employees_df["EmployeeID"].min()
max_eid = employees_df["EmployeeID"].max()
print("Min EmployeeID: ", min_eid)
print("Max EmployeeID: ", max_eid)

# Check employees ids not in the min-max range
missing_employees = set(range(min_eid, max_eid + 1)) - set(employees_df["EmployeeID"])
print("Employees ids not in the min-max range: ", missing_employees)
# Out:
# Min EmployeeID:  1
# Max EmployeeID:  26849
# Employees ids not in the min-max range:  {14976, 22602, 26188, 1423, 4284}

# %% [markdown]
# These might be the "ghosts" agents. Let's quickly check that all managers are also employees just in case...

# %%
managers = set(employees_df["Manager"])
employees = set(employees_df["EmployeeName"])

managers - employees
# Out:
# set()

# %% [markdown]
# Are these "ghosts employees" in other tables?

# %%
divisions_df[divisions_df["EmployeeID"].isin(missing_employees)]
# Out:
#        EmployeeID EmployeeName      Division  \
# 1422         1423          NaN  [Division 7]
# 4283         4284          NaN  [Division 7]
# 14975       14976          NaN  [Division 7]
# 22601       22602          NaN  [Division 7]
# 26187       26188          NaN  [Division 7]
#
#                                                  Project  \
# 1422                  [Project e-enable_holistic_models]
# 4283   [Project repurpose_collaborative_methodologies...
# 14975         [Project transform_24/365_functionalities]
# 22601  [Project monetize_one-to-one_mindshare, Projec...
# 26187               [Project extend_robust_action-items]
#
#               known_safehouses
# 1422       [14, 214, 181, 219]
# 4283                 [10, 219]
# 14975  [25, 154, 231, 33, 219]
# 22601   [12, 221, 19, 18, 219]
# 26187                 [7, 219]

# %% [markdown]
# They all belong to Division 7. What actions did they take?

# %%
actions_df[actions_df["EmployeeID"].isin(missing_employees)].sort_values(["ActionDate"])
# Out:
#        EmployeeID                                  ActionType  \
# 41824       14976                      Quantum Key Generation
# 53036       26188                         Predictive Modeling
# 4283         4284                             Data Clustering
# 81969        1423                              User Profiling
# 68673       14976                 Natural Language Generation
# 31132        4284              Quantum Resistant Cryptography
# 57981        4284  Machine Learning-based Intrusion Detection
# 28271        1423                      Automated Surveillance
# 14975       14976                 Natural Language Generation
# 49450       22602                      Quantum Key Generation
# 55120        1423                      Data Leakage Detection
# 76299       22602                      Cryptocurrency Tracing
# 95522       14976             Pattern-based Malware Detection
# 26187       26188                           Voice Recognition
# 1422         1423                              Video Analysis
# 22601       22602                 Covert Behavioral Analytics
# 79885       26188                             Data Extraction
# 84830        4284              Covert Social Network Analysis
#
#                 ActionDate                                  ActionDescription  \
# 41824  1994-06-06 00:00:00  perform data mining on social media data for s...
# 53036  1994-11-20 00:00:00  construct algorithms for automatic gait recogn...
# 4283   1996-05-08 00:00:00  Initiate operation Networked_discrete_system_e...
# 81969  1997-04-12 00:00:00  Operation Re-contextualized_attitude-oriented_...
# 68673  2007-06-06 00:00:00  construct algorithms for automatic vein recogn...
# 31132  2007-09-17 00:00:00  Initiate operation Customizable_discrete_paral...
# 57981  2007-10-25 00:00:00  analyze communication patterns through Fully-c...
# 28271  2009-10-18 00:00:00  Operation Down-sized_24/7_capability to develo...
# 14975  2011-08-06 00:00:00  Initiate operation Centralized_upward-trending...
# 49450  2012-10-22 00:00:00  Operation Digitized_methodical_structure to ap...
# 55120  2014-05-29 00:00:00  Initiate operation Sharable_impactful_core, ta...
# 76299  2014-08-08 00:00:00  analyze network topology for vulnerabilities t...
# 95522  2015-12-12 00:00:00  utilize machine learning for anomaly detection...
# 26187  2017-10-19 00:00:00  perform text mining on classified documents th...
# 1422   2018-03-01 00:00:00  Initiate operation Digitized_dedicated_help-de...
# 22601  2019-01-30 00:00:00  Operation Vision-oriented_explicit_flexibility...
# 79885  2020-12-01 00:00:00  Initiate operation Realigned_exuding_Graphic_I...
# 84830  2021-03-30 00:00:00  Initiate operation Self-enabling_tangible_webs...
#
#                                      ActionLocation ActionStatus  \
# 41824                                   Puerto Rico    completed
# 53036                                   Puerto Rico       failed
# 4283                                     Martinique    completed
# 81969                                         Egypt       failed
# 68673                                         Benin    completed
# 31132                                    Kazakhstan       failed
# 57981                                       Albania    completed
# 28271                                   Puerto Rico       failed
# 14975                                       Bahrain    completed
# 49450                                       Ireland       failed
# 55120  Antarctica (the territory South of 60 deg S)    completed
# 76299                                    San Marino    completed
# 95522                                Czech Republic    completed
# 26187                                    Bangladesh       failed
# 1422                                        Uruguay       failed
# 22601                                       Ireland       failed
# 79885          United States Minor Outlying Islands  in progress
# 84830                                        Mexico    completed
#
#       ActionSeverity                              AssociatedProject  \
# 41824       critical       Project transform_24/365_functionalities
# 53036       critical             Project extend_robust_action-items
# 4283            high  Project repurpose_collaborative_methodologies
# 81969         medium               Project e-enable_holistic_models
# 68673       critical       Project transform_24/365_functionalities
# 31132       critical  Project repurpose_collaborative_methodologies
# 57981           high  Project repurpose_collaborative_methodologies
# 28271           high               Project e-enable_holistic_models
# 14975            low       Project transform_24/365_functionalities
# 49450           high          Project monetize_one-to-one_mindshare
# 55120            low               Project e-enable_holistic_models
# 76299         medium          Project monetize_one-to-one_mindshare
# 95522       critical       Project transform_24/365_functionalities
# 26187         medium             Project extend_robust_action-items
# 1422             low               Project e-enable_holistic_models
# 22601         medium          Project monetize_one-to-one_mindshare
# 79885            low             Project extend_robust_action-items
# 84830            low  Project repurpose_collaborative_methodologies
#
#       AssociatedDivision
# 41824         Division 1
# 53036        Division 10
# 4283          Division 6
# 81969         Division 3
# 68673         Division 1
# 31132         Division 6
# 57981         Division 6
# 28271         Division 3
# 14975         Division 1
# 49450         Division 6
# 55120         Division 3
# 76299         Division 6
# 95522         Division 1
# 26187        Division 10
# 1422          Division 3
# 22601         Division 6
# 79885        Division 10
# 84830         Division 6

# %% [markdown]
# Some interesting things:
# - They all mention the devices in their action description.
# - They belong to a different Associated Division and not Division 7.
#
# How common is for employees to do actions in other divisions? Time for OBT (one big table).

# %%
detailed_actions_df = actions_df.merge(
    employees_df, left_on="EmployeeID", right_on="EmployeeID", how="left"
).merge(divisions_df, left_on="EmployeeID", right_on="EmployeeID", how="left")
detailed_actions_df.sample(5)
# Out:
#        EmployeeID                   ActionType           ActionDate  \
# 51345       24497              Data Clustering  2004-10-18 00:00:00
# 79376       25679  Natural Language Processing  2000-01-30 00:00:00
# 34640        7792               Image Analysis  1997-09-01 00:00:00
# 82486        1940   Quantum Computing Decoding  2018-08-25 00:00:00
# 36370        9522        DDoS Attack Detection  2007-03-23 00:00:00
#
#                                        ActionDescription ActionLocation  \
# 51345  Initiate operation Decentralized_holistic_defi...     Costa Rica
# 79376  Operation Proactive_maximized_groupware to con...           Iran
# 34640  perform sentiment analysis on customer reviews...       Cambodia
# 82486  Operation Quality-focused_eco-centric_time-fra...         Israel
# 36370  Operation Public-key_systematic_methodology to...   Sierra Leone
#
#       ActionStatus ActionSeverity                        AssociatedProject  \
# 51345    completed           high       Project extend_robust_action-items
# 79376       failed           high      Project drive_value-added_mindshare
# 34640       failed            low  Project deliver_visionary_web-readiness
# 82486       failed       critical    Project mesh_cutting-edge_experiences
# 36370    completed         medium        Project scale_back-end_interfaces
#
#       AssociatedDivision   EmployeeName_x          JobTitle  \
# 51345         Division 1     Jonathan Day      Data Analyst
# 79376         Division 4  Anthony Jackson    Data Scientist
# 34640         Division 9    Bradley Davis      Statistician
# 82486         Division 7    John Thompson  Business Analyst
# 36370         Division 9     Justin Young    Data Scientist
#
#                            Email                  Phone            Manager  \
# 51345     jonathan_day@brlda.gov      931.043.2180x8210         Luis Mccoy
# 79376  anthony_jackson@brlda.gov       001-502-237-1029  Maria Vazquez DVM
# 34640    bradley_davis@brlda.gov             3517150454         Aaron Todd
# 82486    john_thompson@brlda.gov  \t+1-462-677-1117x520     Angela Carlson
# 36370     justin_young@brlda.gov           858.613.0262     Thomas Stewart
#
#         EmployeeName_y                              Division  \
# 51345     Jonathan Day              [Division 1, Division 2]
# 79376  Anthony Jackson  [Division 4, Division 6, Division 4]
# 34640    Bradley Davis                          [Division 9]
# 82486    John Thompson              [Division 8, Division 7]
# 36370     Justin Young  [Division 9, Division 2, Division 5]
#
#                                                  Project  known_safehouses
# 51345  [Project strategize_value-added_bandwidth, Pro...             [211]
# 79376  [Project unleash_front-end_models, Project dri...          [35, 48]
# 34640  [Project deliver_visionary_web-readiness, Proj...          [45, 55]
# 82486            [Project mesh_cutting-edge_experiences]        [133, 193]
# 36370                [Project scale_back-end_interfaces]  [67, 2, 49, 142]

# %%
def check_division_associated_division(row):
    return row["AssociatedDivision"] in row["Division"]


detailed_actions_df[
    ~detailed_actions_df.apply(check_division_associated_division, axis=1)
].sample(5)
# Out:
#        EmployeeID                                       ActionType  \
# 92138       11592                               Data Anonymization
# 40147       13299  Customer Support Interaction Sentiment Analysis
# 87019        6473                       Social Media Post Analysis
# 60427        6730                         Malicious Code Detection
# 75981       22284        Covert Sentiment-based Social Engineering
#
#                 ActionDate                                  ActionDescription  \
# 92138  2006-11-18 00:00:00  analyze network logs for detecting command and...
# 40147  2015-05-19 00:00:00  Operation Cloned_didactic_implementation to ex...
# 87019  2017-12-25 00:00:00  establish covert presence through Optimized_st...
# 60427  1999-06-11 00:00:00  Initiate operation Optional_multimedia_paralle...
# 75981  2018-06-19 00:00:00  perform sentiment analysis on online forums th...
#
#           ActionLocation ActionStatus ActionSeverity  \
# 92138            Andorra    completed       critical
# 40147              Benin       failed            low
# 87019           Slovenia       failed         medium
# 60427          Venezuela    completed           high
# 75981  Wallis and Futuna       failed       critical
#
#                              AssociatedProject AssociatedDivision  \
# 92138    Project mesh_cutting-edge_experiences         Division 7
# 40147         Project embrace_magnetic_systems         Division 7
# 87019     Project embrace_transparent_networks         Division 7
# 60427  Project facilitate_mission-critical_ROI         Division 7
# 75981       Project synergize_B2C_technologies         Division 7
#
#          EmployeeName_x                   JobTitle  \
# 92138     Gabriel Smith             Data Scientist
# 40147      Dillon Moran  Quality Assurance Analyst
# 87019  Melissa Thompson  Machine Learning Engineer
# 60427    Michael Duncan  Machine Learning Engineer
# 75981  Elizabeth Garcia           Business Analyst
#
#                             Email                   Phone  \
# 92138     gabriel_smith@brlda.gov      596.995.7536x22790
# 40147      dillon_moran@brlda.gov   001-124-430-5696x9265
# 87019  melissa_thompson@brlda.gov        001-896-224-3290
# 60427    michael_duncan@brlda.gov  \t+1-112-045-6111x9914
# 75981  elizabeth_garcia@brlda.gov        234.106.8187x788
#
#                     Manager    EmployeeName_y  \
# 92138        Debra Gonzalez     Gabriel Smith
# 40147       Nicholas Davila      Dillon Moran
# 87019          David Rogers  Melissa Thompson
# 60427  Alexander Mccullough    Michael Duncan
# 75981        Paul Robertson  Elizabeth Garcia
#
#                                     Division  \
# 92138               [Division 1, Division 3]
# 40147   [Division 3, Division 2, Division 9]
# 87019   [Division 3, Division 5, Division 3]
# 60427  [Division 8, Division 10, Division 6]
# 75981   [Division 9, Division 5, Division 4]
#
#                                                  Project     known_safehouses
# 92138            [Project mesh_cutting-edge_experiences]        [219, 5, 133]
# 40147  [Project embrace_magnetic_systems, Project e-e...          [140, 4, 1]
# 87019             [Project embrace_transparent_networks]  [157, 231, 51, 232]
# 60427          [Project facilitate_mission-critical_ROI]       [188, 19, 141]
# 75981               [Project synergize_B2C_technologies]           [220, 151]

# %% [markdown]
# Some people did actions associated to Division 7 but is not reflected in the Employee table Divisions.

# %%
detailed_actions_df[
    ~detailed_actions_df.apply(check_division_associated_division, axis=1)
]["AssociatedDivision"].value_counts()
# Out:
# AssociatedDivision
# Division 7     2284
# Division 6        7
# Division 3        4
# Division 1        4
# Division 10       3
# Name: count, dtype: int64

# %% [markdown]
# Now, most of the people that did actions in Division 7 are missclassified, but there are some that did actions in the divisions 1, 3, 6, and 10. These are our suspects.

# %% [markdown]
# ## Safehouses

# %%
safehouses_df.sample(5)
# Out:
#       ID                     City  \
# 198    1                 New York
# 186    6                   London
# 34   183                     Lima
# 81    99  Santa Cruz de la Sierra
# 187    6                    Paris
#
#                                                Address   Latitude  Longitude
# 198  87 Beekman Avenue, Vernon Park, City of Mount ...  40.908226 -73.823729
# 186  20 Robson Avenue, London, NW10 3SZ, United Kin...  51.543403  -0.236712
# 34   Avenida Coronel Néstor Gambetta, 200 Millas, C... -12.004199 -77.124531
# 81   RN9: La Guardia-Abapó, Municipio La Guardia, B... -17.902468 -63.252284
# 187        53 Rue Victor Hugo, 95200 Sarcelles, France  49.001127   2.385609

# %%
# Map of safehouses with Latitude and Longitude
import folium

safehouses_map = folium.Map(
    location=[safehouses_df["Latitude"].mean(), safehouses_df["Longitude"].mean()],
    zoom_start=4,
)

for index, row in safehouses_df.iterrows():
    folium.Marker([row["Latitude"], row["Longitude"]], popup=row["ID"]).add_to(
        safehouses_map
    )

safehouses_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26a9d0f9d0b608349a13352c8c650c10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26a9d0f9d0b608349a13352c8c650c10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26a9d0f9d0b608349a13352c8c650c10 = L.map(
#                 &quot;map_26a9d0f9d0b608349a13352c8c650c10&quot;,
#                 {
#                     center: [19.47703134880941, 7.434807550788163],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2b860719be11edbed3470f439ac598f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26a9d0f9d0b608349a13352c8c650c10);
#
#
#             var marker_b1a55c609faa5a127a6aebbbfad1808d = L.marker(
#                 [22.06871926, 95.9837443],
#                 {}
#             ).addTo(map_26a9d0f9d0b608349a13352c8c650c10);
#
#
#         var popup_be50eee81f8a88a803691d84d7a10d38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34ca0f56c7667a06b94ea6829642ac0e = $(`&lt;div id=&quot;html_34ca0f56c7667a06b94ea6829642ac0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;233&lt;/div&gt;`)[0];
#                 popup_be50eee81f8a88a803691d84d7a10d38.setContent(html_34ca0f56c7667a06b94ea6829642ac0e);
#
#
#
#         marker_b1a55c609faa5a127a6aebbbfad1808d.bindPopup(popup_be50eee81f8a88a803691d84d7a10d38)
#         ;
#
#
#
#
#             var marker_f2c70658811b4b5d08a204178d50f1b8 = L.marker(
#                 [16.69945623, 96.35145029],
#                 {}
#             ).addTo(map_26a9d0f9d0b608349a13352c8c650c10);
#
#
#         var popup_99df857d7d8b75f76c10a9167984f58d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62fb2ccfe4353df4d9f80a2811bc82f3 = $(`&lt;div id=&quot;html_62fb2ccfe4353df4d9f80a2811bc82f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;232&lt;/div&gt;`)[0];
#                 popup_99df857d7d8b75f76c10a9167984f58d.setContent(html_62fb2ccfe4353df4d9f80a2811bc82f3);
#
#
#
#         marker_f2c70658811b4b5d08a204178d50f1b8.bindPopup(popup_99df857d7d8b75f76c10a9167984f58d)
#         ;
#
#
#
#
#             var marker_4f28465fc9d953507958fd4262751aa0 = L.marker(
#                 [19.84308732, 102.159075],
#                 {}
#             ).addTo(map_26a9d0f9d0b608349a13352c8c650c10);
#
#
#         var popup_9ecd7b1edcc04f1fa2151a82eae13618 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bb24ac850042d26a5dff71627cfa68b = $(`&lt;div id=&quot;html_9bb24ac850042d26a5dff71627cfa68b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;231&lt;/div&gt;`)[0];
#                 popup_9ecd7b1edcc04f1fa2151a82eae13618.setContent(html_9bb24ac850042d26a5dff71627cfa68b);
#
#
#
#         marker_4f28465fc9d953507958fd4262751aa0.bindPopup(popup_9ecd7b1edcc04f1fa2151a82eae13618)
#         ;
#
#
#
#
#             var marker_4fe645714c2345bd255bad2926d88318 = L.marker(
#                 [19.85258117, 102.1315775],
#                 {}
#             ).addTo(map_26a9d0f9d0b608349a13352c8c650c10);
#
#
#         var popup_d08c537bf05c1cd63a5c30ec3f0d0066 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec8c5a5a2eb194826eee85a831b2b408 = $(`&lt;div id=&quot;html_ec8c5a5a2eb194826eee85a831b2b408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;230&lt;/div&gt;`)[0];
#                 popup_d08c537bf05c1cd63a5c30ec3f0d0066.setContent(html_ec8c5a5a2eb194826eee85a831b2b408);
#
#
#
#         marker_4fe645714c2345bd255bad2926d88318.bindPopup(popup_d08c537bf05c1cd63a5c30ec3f0d0066)
#         ;
#
#
#
#
#             var marker_c4d7af865b9825911a71e8b9fbbb0725 = L.marker(
#                 [19.88750231, 102.1361868],
#                 {}
#             ).addTo(map_26a9d0f9d0b608349a13352c8c650c10);
#
#
#         var popup_da116a613cf613f71ffac9076ae03af8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5ce2460d0df27bfb3e3c1eeeb73c749 = $(`&lt;div id=&quot;html_c5ce2460d0df27bfb3e3c1eeeb73c749&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;229&lt;/div&gt;`)[0];
#                 popup_da116a613cf613f71ffac9076ae03af8.setContent(html_c5ce2460d0df27bfb3e3c1eeeb73c749);
#
#
#
#         marker_c4d7af865b9825911a71e8b9fbbb0725.bindPopup(popup_da116a613cf613f71ffac9076ae03af8)
#         ;
#
#
#
#
#             var marker_5564950a21f852263c79c301ba335ef7 = L.marker(
#                 [17.89415493, 102.6896173],
#                 {}

# %% [markdown]
# Cute, but not very useful for now, let's explore divisions.

# %% [markdown]
# ## Divisions

# %%
divisions_df
# Out:
#        EmployeeID       EmployeeName                               Division  \
# 0               1         Kelly Rios                           [Division 1]
# 1               2       Madison Barr               [Division 6, Division 3]
# 2               3       Sue Anderson  [Division 5, Division 1, Division 10]
# 3               4      Laura Carlson   [Division 9, Division 9, Division 2]
# 4               5         Carrie Ali               [Division 3, Division 6]
# ...           ...                ...                                    ...
# 26844       26845  Christopher Riley  [Division 8, Division 10, Division 5]
# 26845       26846          Eric Chan   [Division 2, Division 6, Division 1]
# 26846       26847        Amy Vazquez  [Division 8, Division 10, Division 5]
# 26847       26848     Clifford Reyes   [Division 9, Division 2, Division 6]
# 26848       26849        Noah Snyder  [Division 2, Division 9, Division 10]
#
#                                                  Project   known_safehouses
# 0              [Project deliver_visionary_web-readiness]  [232, 1, 73, 217]
# 1        [Project repurpose_collaborative_methodologies]  [192, 26, 118, 4]
# 2        [Project repurpose_collaborative_methodologies]   [19, 8, 130, 50]
# 3               [Project streamline_proactive_e-markets]          [15, 232]
# 4              [Project deliver_visionary_web-readiness]         [158, 118]
# ...                                                  ...                ...
# 26844  [Project drive_value-added_mindshare, Project ...              [226]
# 26845          [Project deliver_visionary_web-readiness]       [15, 99, 58]
# 26846  [Project embrace_transparent_networks, Project...               [22]
# 26847  [Project disintermediate_distributed_experienc...               [98]
# 26848         [Project strategize_value-added_bandwidth]                [1]
#
# [26849 rows x 5 columns]

# %%
# TODO: Explode Division and Project

# %%
# TODO: Some divisions are repeated in Division

# %% [markdown]
# ### Managers

# %%
managers_df.sample(5)
# Out:
#           ManagerName     Employee_1           Employee_2       Employee_3  \
# 3489    Nancy Fleming   Paul Shannon         Adrian Lopez  Nicholas Taylor
# 58     Teresa Johnson  Nathan Gibson      Thomas Jones MD       Adam Stark
# 2060    David Hubbard    Mary Miller      Denise Williams    Michael Grant
# 3126     Joshua Allen  Jenna Shaffer  Christopher Stewart    Heather Ochoa
# 204   Nicole Williams   Lucas Campos          David James   Tracy Franklin
#
#            Employee_4             Employee_5      Employee_6  \
# 3489    David Mcbride  Mr. Jerry Williams II             NaN
# 58     Martha Sanchez       Monique Campbell      Carla Hall
# 2060    Alisha Turner               Amy Soto   Krista Walker
# 3126   Briana Sanchez        Katherine Adams  Katherine Kirk
# 204   Diana Zimmerman      Michelle Anderson   Brett Johnson
#
#               Employee_7       Employee_8      Employee_9  ... Employee_20  \
# 3489                 NaN              NaN             NaN  ...         NaN
# 58    William Harrington     Anthony Paul      Luke Mills  ...         NaN
# 2060     Jasmine Ramirez   Jennifer Mills    Steve Krause  ...         NaN
# 3126                 NaN              NaN             NaN  ...         NaN
# 204   Cassandra Gallegos  Tanner Thompson  Jeremy Hopkins  ...         NaN
#
#      Employee_21 Employee_22 Employee_23 Employee_24 Employee_25 Employee_26  \
# 3489         NaN         NaN         NaN         NaN         NaN         NaN
# 58           NaN         NaN         NaN         NaN         NaN         NaN
# 2060         NaN         NaN         NaN         NaN         NaN         NaN
# 3126         NaN         NaN         NaN         NaN         NaN         NaN
# 204          NaN         NaN         NaN         NaN         NaN         NaN
#
#      Employee_27 Employee_28 Employee_29
# 3489         NaN         NaN         NaN
# 58           NaN         NaN         NaN
# 2060         NaN         NaN         NaN
# 3126         NaN         NaN         NaN
# 204          NaN         NaN         NaN
#
# [5 rows x 30 columns]

# %%
# Transform to long format
clean_managers_df = (
    managers_df.melt(
        id_vars=["ManagerName"], value_name="EmployeeName", var_name="EmployeeNumber"
    )
    .dropna()
    .drop(columns=["EmployeeNumber"])
)

clean_managers_df.sample(5)
# Out:
#             ManagerName      EmployeeName
# 28030     Jeffery Jones   Michael Stevens
# 6700   Alexandra Gibson       Erica Duran
# 1289        Sara Wilcox     Kimberly Webb
# 41082    Brittany Olson  Kimberly Rollins
# 6816       Monica Evans  Patricia Rollins

# %%
managers_df[managers_df["Employee_1"].isna()]
# Out:
#         ManagerName Employee_1 Employee_2 Employee_3 Employee_4 Employee_5  \
# 3686  Jessica Stone        NaN        NaN        NaN        NaN        NaN
#
#      Employee_6 Employee_7 Employee_8 Employee_9  ... Employee_20 Employee_21  \
# 3686        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#      Employee_22 Employee_23 Employee_24 Employee_25 Employee_26 Employee_27  \
# 3686         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Employee_28 Employee_29
# 3686         NaN         NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# Jessica Stone is the only manager without any employees (unless there are NaNs gaps).

# %%
clean_managers_df[clean_managers_df["EmployeeName"] == "Jessica Stone"]
# Out:
#                 ManagerName   EmployeeName
# 17210  Christopher Mckenzie  Jessica Stone

# %%
employees_df[employees_df["EmployeeName"] == "Jessica Stone"]
# Out:
#        EmployeeID   EmployeeName        JobTitle                    Email  \
# 11560       11563  Jessica Stone  Data Scientist  jessica_stone@brlda.gov
#
#                   Phone               Manager
# 11560  001-234-563-9331  Christopher Mckenzie

# %%
divisions_df[divisions_df["EmployeeName"] == "Jessica Stone"]
# Out:
#        EmployeeID   EmployeeName      Division  \
# 11562       11563  Jessica Stone  [Division 4]
#
#                                                  Project known_safehouses
# 11562  [Project mesh_cutting-edge_experiences, Projec...     [18, 42, 44]

# %%
actions_df[actions_df["EmployeeID"] == 11563]
# Out:
#        EmployeeID                        ActionType           ActionDate  \
# 11562       11563               Gesture Recognition  2016-06-21 00:00:00
# 38411       11563  Automated Social Media Profiling  2012-08-31 00:00:00
# 65260       11563                Object Recognition  1996-05-13 00:00:00
# 92109       11563         Covert Facial Recognition  1999-05-26 00:00:00
#
#                                        ActionDescription  \
# 11562  build systems for automatic object detection i...
# 38411  Operation Optimized_real-time_artificial_intel...
# 65260  perform data mining on financial transactions ...
# 92109  Initiate operation Visionary_coherent_architec...
#
#              ActionLocation ActionStatus ActionSeverity  \
# 11562  Syrian Arab Republic       failed       critical
# 38411              Botswana       failed            low
# 65260                 Congo    completed         medium
# 92109                 Italy    completed       critical
#
#                       AssociatedProject AssociatedDivision
# 11562  Project unleash_front-end_models         Division 4
# 38411  Project unleash_front-end_models         Division 4
# 65260  Project unleash_front-end_models         Division 4
# 92109  Project unleash_front-end_models         Division 4

# %% [markdown]
# # Random

# %%
data = pd.merge(employees_df, divisions_df, on=["EmployeeID", "EmployeeName"])
data = pd.merge(data, clean_managers_df, on="EmployeeName", how="left")
data = data[data["Manager"] == data["ManagerName"]]
data.shape
# Out:
# (28316, 10)

# %%
jessica = data[data["EmployeeName"] == "Jessica Stone"]

# %%
MANAGER_WEIGHT = 100
DIVISION_WEIGHT = 10
PROJECT_WEIGHT = 1


def calculate_similarity(emp1, emp2):
    score = 0
    if emp1["ManagerName"] == emp2["ManagerName"]:
        score += MANAGER_WEIGHT
    if bool(set(emp1["Division"]) & set(emp2["Division"])):
        score += DIVISION_WEIGHT
    if bool(set(emp1["Project"]) & set(emp2["Project"])):
        score += PROJECT_WEIGHT
    return score


from itertools import combinations


def top_similarities(data):
    # Create a list to store the results
    similarities = []

    # Calculate the similarity score for each pair of employees
    # for emp1, emp2 in combinations(data.iterrows(), 2):
    #     score = calculate_similarity(emp1[1], emp2[1])
    #     similarities.append(((emp1[1]["EmployeeName"], emp2[1]["EmployeeName"]), score))
    # Calculate the similarity score for each pair of employees
    for emp2 in data.iterrows():
        score = calculate_similarity(jessica.iloc[0], emp2[1])
        similarities.append([emp2[1]["EmployeeName"], score])

    # Sort the results by score in descending order and take the top 100
    similarities.sort(key=lambda x: x[1], reverse=True)
    top_similarities = similarities[:200]

    # Convert the results to a DataFrame
    top_similarities_df = pd.DataFrame(
        top_similarities, columns=["Employee Pair", "Similarity Score"]
    )

    return top_similarities_df


top_similarities_df = top_similarities(data)
top_similarities_df.head(20)
# Out:
#         Employee Pair  Similarity Score
# 0      Kent Hernandez               111
# 1   Daniel Washington               111
# 2       Robert Walter               111
# 3           Jenna Ray               111
# 4       Jessica Stone               111
# 5    Tiffany Oconnell               111
# 6     Brittany Murphy               111
# 7     Michael Freeman               111
# 8         Tyler Owens               111
# 9       Daniel Daniel               111
# 10        Robin Hines               111
# 11         Kelly Rios                11
# 12       Madison Barr                11
# 13       Sue Anderson                11
# 14      Laura Carlson                11
# 15         Carrie Ali                11
# 16   Taylor Patterson                11
# 17      Jessica Brown                11
# 18     Sergio Huffman                11
# 19    Robert Williams                11
