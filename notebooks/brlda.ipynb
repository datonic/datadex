# %% [raw]
# ---
# title: "Bureau of Really Large Data Analysis Leaks"
# format: html
# date: today
# author: "David Gasquez"
# ---

# %% [markdown]
# Let's start by loading the data.

# %%
import pandas as pd

employees_df = pd.read_csv("../data/employees.csv")
safehouses_df = pd.read_csv("../data/safehouses.csv")
divisions_df = pd.read_csv("../data/divisions.csv")
managers_df = pd.read_csv("../data/managers.csv")
actions_df = pd.read_csv("../data/actions.csv")

# %% [markdown]
# ## Employees

# %%
employees_df.sample(5)
# Out:
#        EmployeeID     EmployeeName          JobTitle  \
# 14007       14010    Michael Welch  Business Analyst
# 17813       17817  Melissa Delgado   Project Manager
# 15459       15463     Michael Reid  Business Analyst
# 16765       16769   Lawrence Davis  Business Analyst
# 4937         4940       Lisa Cowan      Statistician
#
#                            Email                 Phone           Manager
# 14007    michael_welch@brlda.gov          614.574.6626   Gregory Wallace
# 17813  melissa_delgado@brlda.gov    819-655-0418x56533  Sheila Mccormick
# 15459     michael_reid@brlda.gov  001-982-363-3908x964  Charles Richards
# 16765   lawrence_davis@brlda.gov          838-728-0122  Melinda Franklin
# 4937        lisa_cowan@brlda.gov    (210)491-5493x0294   Victoria Willis

# %%
employees_df["EmployeeName"].value_counts().head(5)
# Out:
# EmployeeName
# Michael Smith       12
# David Smith         12
# Lisa Smith          11
# John Smith          11
# Michael Williams    10
# Name: count, dtype: int64

# %% [markdown]
# Some duplicate employees are present in the data...

# %%
employees_df[employees_df["EmployeeName"] == "Michael Smith"]
# Out:
#        EmployeeID   EmployeeName                   JobTitle  \
# 4448         4451  Michael Smith            Project Manager
# 5129         5132  Michael Smith               Scrum Master
# 7455         7458  Michael Smith  Quality Assurance Analyst
# 10672       10675  Michael Smith             Data Scientist
# 11683       11686  Michael Smith  Quality Assurance Analyst
# 13957       13960  Michael Smith            Program Manager
# 15668       15672  Michael Smith               Scrum Master
# 17442       17446  Michael Smith               Data Analyst
# 17570       17574  Michael Smith            Program Manager
# 19322       19326  Michael Smith  Machine Learning Engineer
# 22603       22608  Michael Smith            Program Manager
# 23884       23889  Michael Smith            Project Manager
#
#                          Email                    Phone           Manager
# 4448   michael_smith@brlda.gov   001-137-479-2502x05426     Nathan Guerra
# 5129   michael_smith@brlda.gov        223-274-6121x5268     David Houston
# 7455   michael_smith@brlda.gov        (202)737-6861x908       Pamela Hale
# 10672  michael_smith@brlda.gov     001-192-379-3454x580       Sarah Brown
# 11683  michael_smith@brlda.gov     001-038-692-4506x839      Patrick Cruz
# 13957  michael_smith@brlda.gov       (471)896-2210x7208  Heather Crawford
# 15668  michael_smith@brlda.gov       668.014.9966x33380     Gregory Floyd
# 17442  michael_smith@brlda.gov  \t+1-544-294-4533x69316   Richard Collins
# 17570  michael_smith@brlda.gov               9730334254    Michele Graham
# 19322  michael_smith@brlda.gov             081-057-7739      Joshua James
# 22603  michael_smith@brlda.gov    001-714-897-8059x3979      Amber Garcia
# 23884  michael_smith@brlda.gov        \t+1-800-158-9222    Michael Harris

# %% [markdown]
# Are they all the same employee? The email match but the ID and Phone don't.
#
# Let's focus on the missing data. If they removed their users, we should see some missing EmployeeID values.

# %%
# Check min and max EmployeeID
min_eid = employees_df["EmployeeID"].min()
max_eid = employees_df["EmployeeID"].max()
print("Min EmployeeID: ", min_eid)
print("Max EmployeeID: ", max_eid)

# Check employees ids not in the min-max range
missing_employees = set(range(min_eid, max_eid + 1)) - set(employees_df["EmployeeID"])
print("Employees ids not in the min-max range: ", missing_employees)
# Out:
# Min EmployeeID:  1
# Max EmployeeID:  26849
# Employees ids not in the min-max range:  {14976, 22602, 26188, 1423, 4284}

# %% [markdown]
# These might be the "ghosts" agents. Let's quickly check that all managers are also employees just in case...

# %%
managers = set(employees_df["Manager"])
employees = set(employees_df["EmployeeName"])

managers - employees
# Out:
# set()

# %% [markdown]
# Are these "ghosts employees" in other tables?

# %%
divisions_df[divisions_df["EmployeeID"].isin(missing_employees)]
# Out:
#        EmployeeID EmployeeName      Division  \
# 1422         1423          NaN  [Division 7]
# 4283         4284          NaN  [Division 7]
# 14975       14976          NaN  [Division 7]
# 22601       22602          NaN  [Division 7]
# 26187       26188          NaN  [Division 7]
#
#                                                  Project  \
# 1422                  [Project e-enable_holistic_models]
# 4283   [Project repurpose_collaborative_methodologies...
# 14975         [Project transform_24/365_functionalities]
# 22601  [Project monetize_one-to-one_mindshare, Projec...
# 26187               [Project extend_robust_action-items]
#
#               known_safehouses
# 1422       [14, 214, 181, 219]
# 4283                 [10, 219]
# 14975  [25, 154, 231, 33, 219]
# 22601   [12, 221, 19, 18, 219]
# 26187                 [7, 219]

# %% [markdown]
# They all belong to Division 7. What actions did they take?

# %%
actions_df[actions_df["EmployeeID"].isin(missing_employees)].sort_values(["ActionDate"])
# Out:
#        EmployeeID                                  ActionType  \
# 41824       14976                      Quantum Key Generation
# 53036       26188                         Predictive Modeling
# 4283         4284                             Data Clustering
# 81969        1423                              User Profiling
# 68673       14976                 Natural Language Generation
# 31132        4284              Quantum Resistant Cryptography
# 57981        4284  Machine Learning-based Intrusion Detection
# 28271        1423                      Automated Surveillance
# 14975       14976                 Natural Language Generation
# 49450       22602                      Quantum Key Generation
# 55120        1423                      Data Leakage Detection
# 76299       22602                      Cryptocurrency Tracing
# 95522       14976             Pattern-based Malware Detection
# 26187       26188                           Voice Recognition
# 1422         1423                              Video Analysis
# 22601       22602                 Covert Behavioral Analytics
# 79885       26188                             Data Extraction
# 84830        4284              Covert Social Network Analysis
#
#                 ActionDate                                  ActionDescription  \
# 41824  1994-06-06 00:00:00  perform data mining on social media data for s...
# 53036  1994-11-20 00:00:00  construct algorithms for automatic gait recogn...
# 4283   1996-05-08 00:00:00  Initiate operation Networked_discrete_system_e...
# 81969  1997-04-12 00:00:00  Operation Re-contextualized_attitude-oriented_...
# 68673  2007-06-06 00:00:00  construct algorithms for automatic vein recogn...
# 31132  2007-09-17 00:00:00  Initiate operation Customizable_discrete_paral...
# 57981  2007-10-25 00:00:00  analyze communication patterns through Fully-c...
# 28271  2009-10-18 00:00:00  Operation Down-sized_24/7_capability to develo...
# 14975  2011-08-06 00:00:00  Initiate operation Centralized_upward-trending...
# 49450  2012-10-22 00:00:00  Operation Digitized_methodical_structure to ap...
# 55120  2014-05-29 00:00:00  Initiate operation Sharable_impactful_core, ta...
# 76299  2014-08-08 00:00:00  analyze network topology for vulnerabilities t...
# 95522  2015-12-12 00:00:00  utilize machine learning for anomaly detection...
# 26187  2017-10-19 00:00:00  perform text mining on classified documents th...
# 1422   2018-03-01 00:00:00  Initiate operation Digitized_dedicated_help-de...
# 22601  2019-01-30 00:00:00  Operation Vision-oriented_explicit_flexibility...
# 79885  2020-12-01 00:00:00  Initiate operation Realigned_exuding_Graphic_I...
# 84830  2021-03-30 00:00:00  Initiate operation Self-enabling_tangible_webs...
#
#                                      ActionLocation ActionStatus  \
# 41824                                   Puerto Rico    completed
# 53036                                   Puerto Rico       failed
# 4283                                     Martinique    completed
# 81969                                         Egypt       failed
# 68673                                         Benin    completed
# 31132                                    Kazakhstan       failed
# 57981                                       Albania    completed
# 28271                                   Puerto Rico       failed
# 14975                                       Bahrain    completed
# 49450                                       Ireland       failed
# 55120  Antarctica (the territory South of 60 deg S)    completed
# 76299                                    San Marino    completed
# 95522                                Czech Republic    completed
# 26187                                    Bangladesh       failed
# 1422                                        Uruguay       failed
# 22601                                       Ireland       failed
# 79885          United States Minor Outlying Islands  in progress
# 84830                                        Mexico    completed
#
#       ActionSeverity                              AssociatedProject  \
# 41824       critical       Project transform_24/365_functionalities
# 53036       critical             Project extend_robust_action-items
# 4283            high  Project repurpose_collaborative_methodologies
# 81969         medium               Project e-enable_holistic_models
# 68673       critical       Project transform_24/365_functionalities
# 31132       critical  Project repurpose_collaborative_methodologies
# 57981           high  Project repurpose_collaborative_methodologies
# 28271           high               Project e-enable_holistic_models
# 14975            low       Project transform_24/365_functionalities
# 49450           high          Project monetize_one-to-one_mindshare
# 55120            low               Project e-enable_holistic_models
# 76299         medium          Project monetize_one-to-one_mindshare
# 95522       critical       Project transform_24/365_functionalities
# 26187         medium             Project extend_robust_action-items
# 1422             low               Project e-enable_holistic_models
# 22601         medium          Project monetize_one-to-one_mindshare
# 79885            low             Project extend_robust_action-items
# 84830            low  Project repurpose_collaborative_methodologies
#
#       AssociatedDivision
# 41824         Division 1
# 53036        Division 10
# 4283          Division 6
# 81969         Division 3
# 68673         Division 1
# 31132         Division 6
# 57981         Division 6
# 28271         Division 3
# 14975         Division 1
# 49450         Division 6
# 55120         Division 3
# 76299         Division 6
# 95522         Division 1
# 26187        Division 10
# 1422          Division 3
# 22601         Division 6
# 79885        Division 10
# 84830         Division 6

# %% [markdown]
# Some interesting things:
# - They all mention the devices in their action description.
# - They belong to a different Associated Division and not Division 7.
#
# How common is for employees to do actions in other divisions? Time for OBT (one big table).

# %%
detailed_actions_df = actions_df.merge(
    employees_df, left_on="EmployeeID", right_on="EmployeeID", how="left"
).merge(divisions_df, left_on="EmployeeID", right_on="EmployeeID", how="left")
detailed_actions_df.sample(5)
# Out:
#        EmployeeID                       ActionType           ActionDate  \
# 15083       15084           Quantum Key Generation  2016-11-29 00:00:00
# 21036       21037  Network Covert Channel Analysis  2022-02-01 00:00:00
# 21892       21893      Quantitative Credit Scoring  2019-02-14 00:00:00
# 65991       12294                Digital Forensics  2019-05-15 00:00:00
# 13255       13256  Covert Biometric Identification  2002-08-02 00:00:00
#
#                                        ActionDescription  ActionLocation  \
# 15083  Initiate operation Implemented_modular_attitud...     Philippines
# 21036  Operation Profit-focused_6thgeneration_install...  Western Sahara
# 21892  Initiate operation Open-source_solution-orient...        Cambodia
# 65991  develop algorithms for automatic speech recogn...        Paraguay
# 13255  construct algorithms for intrusion detection i...     El Salvador
#
#       ActionStatus ActionSeverity                        AssociatedProject  \
# 15083    completed            low   Project streamline_proactive_e-markets
# 21036  in progress           high   Project streamline_proactive_e-markets
# 21892    completed       critical  Project deliver_visionary_web-readiness
# 65991    completed           high    Project mesh_cutting-edge_experiences
# 13255    completed       critical  Project facilitate_mission-critical_ROI
#
#       AssociatedDivision   EmployeeName_x         JobTitle  \
# 15083         Division 3  Jessica Jackson     Statistician
# 21036         Division 4     Lisa Mccarty     Data Analyst
# 21892         Division 4      Terry Clark  Project Manager
# 65991         Division 4      Chris Smith  Program Manager
# 13255         Division 9  Timothy Johnson  Program Manager
#
#                            Email                   Phone         Manager  \
# 15083  jessica_jackson@brlda.gov       \t+1-852-619-7576   Pamela Nelson
# 21036     lisa_mccarty@brlda.gov            961.555.0296    Darius Davis
# 21892      terry_clark@brlda.gov    001-856-450-8917x357  Crystal Romero
# 65991      chris_smith@brlda.gov  001-606-260-6378x35048     Bryan Moore
# 13255  timothy_johnson@brlda.gov            887-799-0591    James Rogers
#
#         EmployeeName_y                              Division  \
# 15083  Jessica Jackson              [Division 9, Division 3]
# 21036     Lisa Mccarty                          [Division 4]
# 21892      Terry Clark  [Division 3, Division 4, Division 8]
# 65991      Chris Smith                          [Division 4]
# 13255  Timothy Johnson             [Division 9, Division 10]
#
#                                                  Project    known_safehouses
# 15083  [Project unleash_front-end_models, Project str...  [4, 232, 110, 220]
# 21036           [Project streamline_proactive_e-markets]  [31, 33, 155, 152]
# 21892  [Project monetize_one-to-one_mindshare, Projec...        [20, 36, 20]
# 65991  [Project monetize_one-to-one_mindshare, Projec...                [63]
# 13255  [Project facilitate_mission-critical_ROI, Proj...    [13, 19, 1, 191]

# %%
def check_division_associated_division(row):
    return row["AssociatedDivision"] in row["Division"]


detailed_actions_df[
    ~detailed_actions_df.apply(check_division_associated_division, axis=1)
].sample(5)
# Out:
#        EmployeeID                       ActionType           ActionDate  \
# 35605        8757  Pattern-based Malware Detection  2001-10-17 00:00:00
# 77354       23657           Quantum Key Generation  2021-12-01 00:00:00
# 23463       23464                 Malware Analysis  2008-07-20 00:00:00
# 31975        5127                Data Steganalysis  2018-03-08 00:00:00
# 18674       18675              Data Access Control  2006-04-25 00:00:00
#
#                                        ActionDescription  \
# 35605  Initiate operation Adaptive_next_generation_le...
# 77354  Operation Cross-group_system-worthy_function t...
# 23463  Initiate operation Expanded_24hour_firmware, t...
# 31975  Initiate operation Synchronized_responsive_kno...
# 18674  Operation Pre-emptive_object-oriented_adapter ...
#
#                ActionLocation ActionStatus ActionSeverity  \
# 35605                  Tuvalu       failed            low
# 77354        Marshall Islands       failed         medium
# 23463  British Virgin Islands    completed           high
# 31975                  Greece       failed           high
# 18674    Syrian Arab Republic       failed       critical
#
#                                    AssociatedProject AssociatedDivision  \
# 35605  Project repurpose_collaborative_methodologies         Division 7
# 77354        Project facilitate_mission-critical_ROI         Division 7
# 23463          Project monetize_one-to-one_mindshare         Division 7
# 31975               Project embrace_magnetic_systems         Division 7
# 18674           Project engineer_killer_applications         Division 7
#
#         EmployeeName_x          JobTitle                      Email  \
# 35605  Kimberly Mccann   Project Manager  kimberly_mccann@brlda.gov
# 77354    Michael Garza  Business Analyst    michael_garza@brlda.gov
# 23463     Matthew Boyd   Program Manager     matthew_boyd@brlda.gov
# 31975    Audrey Peters  Business Analyst    audrey_peters@brlda.gov
# 18674      John Willis      Scrum Master      john_willis@brlda.gov
#
#                         Phone              Manager   EmployeeName_y  \
# 35605  \t+1-751-319-4440x1839  Christopher Sanchez  Kimberly Mccann
# 77354        001-960-646-5296    Brandon Wiley Jr.    Michael Garza
# 23463       953-103-4209x1001       Crystal Harris     Matthew Boyd
# 31975  \t+1-512-390-9160x5974          Shane Cowan    Audrey Peters
# 18674        001-930-326-5306          James Frost      John Willis
#
#                                     Division  \
# 35605   [Division 9, Division 2, Division 2]
# 77354  [Division 10, Division 4, Division 6]
# 23463  [Division 2, Division 2, Division 10]
# 31975   [Division 8, Division 9, Division 2]
# 18674  [Division 10, Division 5, Division 9]
#
#                                                  Project    known_safehouses
# 35605    [Project repurpose_collaborative_methodologies]                [77]
# 77354  [Project scale_back-end_interfaces, Project di...      [111, 46, 149]
# 23463            [Project monetize_one-to-one_mindshare]      [19, 121, 152]
# 31975  [Project drive_value-added_mindshare, Project ...     [224, 193, 129]
# 18674             [Project engineer_killer_applications]  [21, 50, 110, 152]

# %% [markdown]
# Some people did actions associated to Division 7 but is not reflected in the Employee table Divisions.

# %%
detailed_actions_df[
    ~detailed_actions_df.apply(check_division_associated_division, axis=1)
]["AssociatedDivision"].value_counts()
# Out:
# AssociatedDivision
# Division 7     2284
# Division 6        7
# Division 3        4
# Division 1        4
# Division 10       3
# Name: count, dtype: int64

# %% [markdown]
# Now, most of the people that did actions in Division 7 are missclassified, but there are some that did actions in the divisions 1, 3, 6, and 10. These are our suspects.

# %% [markdown]
# ## Safehouses

# %%
safehouses_df.sample(5)
# Out:
#       ID           City                                            Address  \
# 41   158         Moscow  Izmaylovo Manor, Первомайская улица, Izmaylovo...
# 169   13         Moscow  Детский оздоровительный лагерь "Искорка", М-2,...
# 25   192           Rome  Maiorana, Via Bolognola, 63, 00138 Rome RM, Italy
# 120   43        Jakarta  Jalan Zeni AD I, Pancoran, Special Capital Reg...
# 2    231  Luang Prabang                      13, 10554 Khouathineung, Laos
#
#       Latitude   Longitude
# 41   55.794138   37.757960
# 169  55.363000   37.727959
# 25   41.987777   12.503599
# 120  -6.260742  106.856980
# 2    19.843087  102.159075

# %%
# Map of safehouses with Latitude and Longitude
import folium

safehouses_map = folium.Map(
    location=[safehouses_df["Latitude"].mean(), safehouses_df["Longitude"].mean()],
    zoom_start=4,
)

for index, row in safehouses_df.iterrows():
    folium.Marker([row["Latitude"], row["Longitude"]], popup=row["ID"]).add_to(
        safehouses_map
    )

safehouses_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1071bbaa64eb0b158a0075cf1d637d2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1071bbaa64eb0b158a0075cf1d637d2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1071bbaa64eb0b158a0075cf1d637d2a = L.map(
#                 &quot;map_1071bbaa64eb0b158a0075cf1d637d2a&quot;,
#                 {
#                     center: [19.47703134880941, 7.434807550788163],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b43f21fc5758b5bd2b670b5654064a49 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1071bbaa64eb0b158a0075cf1d637d2a);
#
#
#             var marker_e792ec45e2c4c739651598403ff8e432 = L.marker(
#                 [22.06871926, 95.9837443],
#                 {}
#             ).addTo(map_1071bbaa64eb0b158a0075cf1d637d2a);
#
#
#         var popup_3b663f1ef3fac4789d39622d34036537 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58d1cd0348d95011ba0233eca9af05ba = $(`&lt;div id=&quot;html_58d1cd0348d95011ba0233eca9af05ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;233&lt;/div&gt;`)[0];
#                 popup_3b663f1ef3fac4789d39622d34036537.setContent(html_58d1cd0348d95011ba0233eca9af05ba);
#
#
#
#         marker_e792ec45e2c4c739651598403ff8e432.bindPopup(popup_3b663f1ef3fac4789d39622d34036537)
#         ;
#
#
#
#
#             var marker_e423566c4227328de64e4e24af2636be = L.marker(
#                 [16.69945623, 96.35145029],
#                 {}
#             ).addTo(map_1071bbaa64eb0b158a0075cf1d637d2a);
#
#
#         var popup_67d146c26501806819658ca6bef8bad9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e11f690dae28eb906d03f41cfe9a000 = $(`&lt;div id=&quot;html_8e11f690dae28eb906d03f41cfe9a000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;232&lt;/div&gt;`)[0];
#                 popup_67d146c26501806819658ca6bef8bad9.setContent(html_8e11f690dae28eb906d03f41cfe9a000);
#
#
#
#         marker_e423566c4227328de64e4e24af2636be.bindPopup(popup_67d146c26501806819658ca6bef8bad9)
#         ;
#
#
#
#
#             var marker_2ad445ff7074bfc31f808294e73bffa8 = L.marker(
#                 [19.84308732, 102.159075],
#                 {}
#             ).addTo(map_1071bbaa64eb0b158a0075cf1d637d2a);
#
#
#         var popup_d92522da15fed98cad4de49400ec9620 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4803914f0285eb3258b2e8d543922ef2 = $(`&lt;div id=&quot;html_4803914f0285eb3258b2e8d543922ef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;231&lt;/div&gt;`)[0];
#                 popup_d92522da15fed98cad4de49400ec9620.setContent(html_4803914f0285eb3258b2e8d543922ef2);
#
#
#
#         marker_2ad445ff7074bfc31f808294e73bffa8.bindPopup(popup_d92522da15fed98cad4de49400ec9620)
#         ;
#
#
#
#
#             var marker_cc607b1bace1f0b73ac22b6161c67da0 = L.marker(
#                 [19.85258117, 102.1315775],
#                 {}
#             ).addTo(map_1071bbaa64eb0b158a0075cf1d637d2a);
#
#
#         var popup_8d9a3a7ac272d6adb4c1653511b6103c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7a7373588ba1903d536e511f38a512a = $(`&lt;div id=&quot;html_e7a7373588ba1903d536e511f38a512a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;230&lt;/div&gt;`)[0];
#                 popup_8d9a3a7ac272d6adb4c1653511b6103c.setContent(html_e7a7373588ba1903d536e511f38a512a);
#
#
#
#         marker_cc607b1bace1f0b73ac22b6161c67da0.bindPopup(popup_8d9a3a7ac272d6adb4c1653511b6103c)
#         ;
#
#
#
#
#             var marker_29894c6e0a7102fffd02b6ceb4e52f5a = L.marker(
#                 [19.88750231, 102.1361868],
#                 {}
#             ).addTo(map_1071bbaa64eb0b158a0075cf1d637d2a);
#
#
#         var popup_7646127833ee5b83b9e97fa269d199bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae9bdcccef102df40960065bac5a12bd = $(`&lt;div id=&quot;html_ae9bdcccef102df40960065bac5a12bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;229&lt;/div&gt;`)[0];
#                 popup_7646127833ee5b83b9e97fa269d199bc.setContent(html_ae9bdcccef102df40960065bac5a12bd);
#
#
#
#         marker_29894c6e0a7102fffd02b6ceb4e52f5a.bindPopup(popup_7646127833ee5b83b9e97fa269d199bc)
#         ;
#
#
#
#
#             var marker_3d255dbf69623dcf55dac7d8d6445bbf = L.marker(
#                 [17.89415493, 102.6896173],
#                 {}

# %% [markdown]
# Cute, but not very useful for now, let's explore divisions.

# %% [markdown]
# ## Divisions

# %%
divisions_df
# Out:
#        EmployeeID       EmployeeName                               Division  \
# 0               1         Kelly Rios                           [Division 1]
# 1               2       Madison Barr               [Division 6, Division 3]
# 2               3       Sue Anderson  [Division 5, Division 1, Division 10]
# 3               4      Laura Carlson   [Division 9, Division 9, Division 2]
# 4               5         Carrie Ali               [Division 3, Division 6]
# ...           ...                ...                                    ...
# 26844       26845  Christopher Riley  [Division 8, Division 10, Division 5]
# 26845       26846          Eric Chan   [Division 2, Division 6, Division 1]
# 26846       26847        Amy Vazquez  [Division 8, Division 10, Division 5]
# 26847       26848     Clifford Reyes   [Division 9, Division 2, Division 6]
# 26848       26849        Noah Snyder  [Division 2, Division 9, Division 10]
#
#                                                  Project   known_safehouses
# 0              [Project deliver_visionary_web-readiness]  [232, 1, 73, 217]
# 1        [Project repurpose_collaborative_methodologies]  [192, 26, 118, 4]
# 2        [Project repurpose_collaborative_methodologies]   [19, 8, 130, 50]
# 3               [Project streamline_proactive_e-markets]          [15, 232]
# 4              [Project deliver_visionary_web-readiness]         [158, 118]
# ...                                                  ...                ...
# 26844  [Project drive_value-added_mindshare, Project ...              [226]
# 26845          [Project deliver_visionary_web-readiness]       [15, 99, 58]
# 26846  [Project embrace_transparent_networks, Project...               [22]
# 26847  [Project disintermediate_distributed_experienc...               [98]
# 26848         [Project strategize_value-added_bandwidth]                [1]
#
# [26849 rows x 5 columns]

# %% [markdown]
# ### Managers

# %%
managers_df.sample(5)
# Out:
#             ManagerName        Employee_1     Employee_2        Employee_3  \
# 601   Michael Payne DDS      Susan Hanson  Heather Brown        Megan Mayo
# 2542      Mark Marshall  Christopher Lang      Dawn Diaz      Teresa Woods
# 2413     Sharon Salazar     Jacob Stanley   Brooke Perry       Lori Riddle
# 3246     Amanda Daniels    Abigail Acosta   Connie Davis    Christina Vang
# 3445     Renee Gonzales   Caroline Rogers   Adam Sanchez  Mr. James Melton
#
#            Employee_4         Employee_5          Employee_6     Employee_7  \
# 601     Rachel Nguyen         Nancy West  Jennifer Rodriguez   Carol Norton
# 2542  Anthony Garrett      Robert Hodges           Holly Kim            NaN
# 2413        Kelly Lin  Jennifer Matthews        Anthony West  Jason Hawkins
# 3246   Cynthia Morris       Lauren Walsh     Claire Chandler  Joseph Nelson
# 3445     Tanner Villa       Candice Mann                 NaN            NaN
#
#          Employee_8       Employee_9  ... Employee_20 Employee_21 Employee_22  \
# 601             NaN              NaN  ...         NaN         NaN         NaN
# 2542            NaN              NaN  ...         NaN         NaN         NaN
# 2413  Kimberly Wood  Jared Zimmerman  ...         NaN         NaN         NaN
# 3246  Tiffany Mckee              NaN  ...         NaN         NaN         NaN
# 3445            NaN              NaN  ...         NaN         NaN         NaN
#
#      Employee_23 Employee_24 Employee_25 Employee_26 Employee_27 Employee_28  \
# 601          NaN         NaN         NaN         NaN         NaN         NaN
# 2542         NaN         NaN         NaN         NaN         NaN         NaN
# 2413         NaN         NaN         NaN         NaN         NaN         NaN
# 3246         NaN         NaN         NaN         NaN         NaN         NaN
# 3445         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Employee_29
# 601          NaN
# 2542         NaN
# 2413         NaN
# 3246         NaN
# 3445         NaN
#
# [5 rows x 30 columns]

# %%
# Transform to long format
clean_managers_df = (
    managers_df.melt(
        id_vars=["ManagerName"], value_name="EmployeeName", var_name="EmployeeNumber"
    )
    .dropna()
    .drop(columns=["EmployeeNumber"])
)

clean_managers_df.sample(5)
# Out:
#              ManagerName    EmployeeName
# 17713     Andrew Collins     Amber Myers
# 10222         Todd Ayala  Antonio Steele
# 26918  Brandon Wiley Jr.   Herbert Moore
# 6747         Todd Wilson    Kenneth Reed
# 24041        Lisa Bowman     Tracy Burns

# %%
managers_df[managers_df["Employee_1"].isna()]
# Out:
#         ManagerName Employee_1 Employee_2 Employee_3 Employee_4 Employee_5  \
# 3686  Jessica Stone        NaN        NaN        NaN        NaN        NaN
#
#      Employee_6 Employee_7 Employee_8 Employee_9  ... Employee_20 Employee_21  \
# 3686        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#      Employee_22 Employee_23 Employee_24 Employee_25 Employee_26 Employee_27  \
# 3686         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Employee_28 Employee_29
# 3686         NaN         NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# Jessica Stone is the only manager without any employees (unless there are NaNs gaps).

# %%
clean_managers_df[clean_managers_df["EmployeeName"] == "Jessica Stone"]
# Out:
#                 ManagerName   EmployeeName
# 17210  Christopher Mckenzie  Jessica Stone

# %%
employees_df[employees_df["EmployeeName"] == "Jessica Stone"]
# Out:
#        EmployeeID   EmployeeName        JobTitle                    Email  \
# 11560       11563  Jessica Stone  Data Scientist  jessica_stone@brlda.gov
#
#                   Phone               Manager
# 11560  001-234-563-9331  Christopher Mckenzie

# %%
divisions_df[divisions_df["EmployeeName"] == "Jessica Stone"]
# Out:
#        EmployeeID   EmployeeName      Division  \
# 11562       11563  Jessica Stone  [Division 4]
#
#                                                  Project known_safehouses
# 11562  [Project mesh_cutting-edge_experiences, Projec...     [18, 42, 44]

# %%
actions_df[actions_df["EmployeeID"] == 11563]
# Out:
#        EmployeeID                        ActionType           ActionDate  \
# 11562       11563               Gesture Recognition  2016-06-21 00:00:00
# 38411       11563  Automated Social Media Profiling  2012-08-31 00:00:00
# 65260       11563                Object Recognition  1996-05-13 00:00:00
# 92109       11563         Covert Facial Recognition  1999-05-26 00:00:00
#
#                                        ActionDescription  \
# 11562  build systems for automatic object detection i...
# 38411  Operation Optimized_real-time_artificial_intel...
# 65260  perform data mining on financial transactions ...
# 92109  Initiate operation Visionary_coherent_architec...
#
#              ActionLocation ActionStatus ActionSeverity  \
# 11562  Syrian Arab Republic       failed       critical
# 38411              Botswana       failed            low
# 65260                 Congo    completed         medium
# 92109                 Italy    completed       critical
#
#                       AssociatedProject AssociatedDivision
# 11562  Project unleash_front-end_models         Division 4
# 38411  Project unleash_front-end_models         Division 4
# 65260  Project unleash_front-end_models         Division 4
# 92109  Project unleash_front-end_models         Division 4

# %% [markdown]
# ## Event Log

# %%
event_log = pd.read_csv("../data/event_log.csv")
event_log
# Out:
#          timestamp       event_type   latitude   longitude
# 0       1973-01-11  device_sighting  36.120243 -115.165881
# 1       1973-01-11  device_sighting  36.121162 -115.166821
# 2       1973-01-11  device_sighting  36.122059 -115.167754
# 3       1973-01-11  device_sighting  36.122927 -115.168672
# 4       1973-01-11  device_sighting  36.123756 -115.169568
# ...            ...              ...        ...         ...
# 239493  1997-11-14   intel_analysis  12.780501 -110.231854
# 239494  1981-08-27   intel_analysis  12.352336   23.379725
# 239495  1998-05-04   intel_analysis -88.566131 -144.912711
# 239496  2009-11-08   intel_analysis  -6.631462  -74.687310
# 239497  1978-04-15   intel_analysis  83.942994 -138.221418
#
# [239498 rows x 4 columns]

# %%
# Get devide_sighting type
device_sighting = event_log[event_log["event_type"] == "device_sighting"]

# %%
# Plot map with lines between device_sighting
device_sighting_map = folium.Map(
    location=[device_sighting["latitude"].mean(), device_sighting["longitude"].mean()],
    zoom_start=4,
)

for index, row in device_sighting.iterrows():
    previous_row = device_sighting.iloc[index - 1]

    folium.CircleMarker(
        [row["latitude"], row["longitude"]],
        radius=5,
        popup=[row["latitude"], row["longitude"]],
        color="#3186cc",
        fill=True,
        fill_color="#3186cc",
    ).add_to(device_sighting_map)

    # Add Lines
    if index > 0:
        folium.PolyLine(
            [
                (row["latitude"], row["longitude"]),
                (previous_row["latitude"], previous_row["longitude"]),
            ],
            color="red",
            weight=1,
            opacity=0.5,
        ).add_to(device_sighting_map)
# Add safehouses
for index, safehouse in safehouses_df.iterrows():
    folium.Marker(
        [safehouse["Latitude"], safehouse["Longitude"]],
        popup=safehouse["ID"],
        icon=folium.Icon(color="green", icon="home"),
    ).add_to(device_sighting_map)

device_sighting_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53fd216e50e683ef351e208d7d238835 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53fd216e50e683ef351e208d7d238835&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53fd216e50e683ef351e208d7d238835 = L.map(
#                 &quot;map_53fd216e50e683ef351e208d7d238835&quot;,
#                 {
#                     center: [35.057056532823054, -111.33702066349746],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3c1af39634e08a7051e10c4e0e5758c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_53fd216e50e683ef351e208d7d238835);
#
#
#             var circle_marker_fbaf2373221d5d2e916ae3eae82eac2f = L.circleMarker(
#                 [36.12024254520539, -115.16588108533936],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53fd216e50e683ef351e208d7d238835);
#
#
#         var popup_8dea8acb7c4e496c4295dfb66a7ab630 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ad2d38775d254d5f55ebe4f591f74b7 = $(`&lt;div id=&quot;html_8ad2d38775d254d5f55ebe4f591f74b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[36.12024254520539, -115.16588108533936]&lt;/div&gt;`)[0];
#                 popup_8dea8acb7c4e496c4295dfb66a7ab630.setContent(html_8ad2d38775d254d5f55ebe4f591f74b7);
#
#
#
#         circle_marker_fbaf2373221d5d2e916ae3eae82eac2f.bindPopup(popup_8dea8acb7c4e496c4295dfb66a7ab630)
#         ;
#
#
#
#
#             var circle_marker_03b7210d57f7afa7f64853978f140b7e = L.circleMarker(
#                 [36.12116208049999, -115.16682051321952],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53fd216e50e683ef351e208d7d238835);
#
#
#         var popup_f6fc38d073e4d41018fcd233fd38a5ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb9f84454ff2c0de069ec0986052e8cc = $(`&lt;div id=&quot;html_fb9f84454ff2c0de069ec0986052e8cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[36.12116208049999, -115.16682051321952]&lt;/div&gt;`)[0];
#                 popup_f6fc38d073e4d41018fcd233fd38a5ec.setContent(html_fb9f84454ff2c0de069ec0986052e8cc);
#
#
#
#         circle_marker_03b7210d57f7afa7f64853978f140b7e.bindPopup(popup_f6fc38d073e4d41018fcd233fd38a5ec)
#         ;
#
#
#
#
#             var poly_line_8307b18d18118c563bc3dbb2071a7d6a = L.polyline(
#                 [[36.12116208049999, -115.16682051321952], [36.12024254520539, -115.16588108533936]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_53fd216e50e683ef351e208d7d238835);
#
#
#             var circle_marker_1ad574a8468689ea68ffb9aa8f4c05d0 = L.circleMarker(
#                 [36.12205937528872, -115.16775362532664],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53fd216e50e683ef351e208d7d238835);

# %%
actions_df[actions_df["EmployeeID"] == 22602]
# Out:
#        EmployeeID                   ActionType           ActionDate  \
# 22601       22602  Covert Behavioral Analytics  2019-01-30 00:00:00
# 49450       22602       Quantum Key Generation  2012-10-22 00:00:00
# 76299       22602       Cryptocurrency Tracing  2014-08-08 00:00:00
#
#                                        ActionDescription ActionLocation  \
# 22601  Operation Vision-oriented_explicit_flexibility...        Ireland
# 49450  Operation Digitized_methodical_structure to ap...        Ireland
# 76299  analyze network topology for vulnerabilities t...     San Marino
#
#       ActionStatus ActionSeverity                      AssociatedProject  \
# 22601       failed         medium  Project monetize_one-to-one_mindshare
# 49450       failed           high  Project monetize_one-to-one_mindshare
# 76299    completed         medium  Project monetize_one-to-one_mindshare
#
#       AssociatedDivision
# 22601         Division 6
# 49450         Division 6
# 76299         Division 6
