# %% [raw]
# ---
# title: "Bureau of Really Large Data Analysis Leaks"
# format: html
# ---

# %% [markdown]
# Let's start by loading the data and taking a look at it.

# %%
import pandas as pd

employees_df = pd.read_csv("../data/employees.csv")
safehouses_df = pd.read_csv("../data/safehouses.csv")
divisions_df = pd.read_csv("../data/divisions.csv")
managers_df = pd.read_csv("../data/managers.csv")
actions_df = pd.read_csv("../data/actions.csv")

# %% [markdown]
# ## Employees

# %%
employees_df.sample(5)
# Out:
#        EmployeeID     EmployeeName         JobTitle  \
# 18217       18221  Jonathan Barber     Data Analyst
# 25455       25460       Luis Hobbs     Scrum Master
# 9952         9955   Adrienne Green     Data Analyst
# 9720         9723    Stephen Smith     Scrum Master
# 2487         2489  Patrick Benitez  Project Manager
#
#                            Email                   Phone             Manager
# 18217  jonathan_barber@brlda.gov       (709)358-0654x450      Theresa Rhodes
# 25455       luis_hobbs@brlda.gov   001-783-416-2922x9352  Dr. Charlene Hicks
# 9952    adrienne_green@brlda.gov           (357)404-7351        Jasmine Ford
# 9720     stephen_smith@brlda.gov       250.989.9731x1477          Donna Ross
# 2487   patrick_benitez@brlda.gov  \t+1-087-924-1347x1681       Terry Carroll

# %% [markdown]
# If they removed their users, we should see some missing EmployeeID values.

# %%
# Check min and max EmployeeID
min_eid = employees_df["EmployeeID"].min()
max_eid = employees_df["EmployeeID"].max()
print("Min EmployeeID: ", min_eid)
print("Max EmployeeID: ", max_eid)

# Check employees ids not in the min-max range
missing_employees = set(range(min_eid, max_eid + 1)) - set(employees_df["EmployeeID"])
print("Employees ids not in the min-max range: ", missing_employees)
# Out:
# Min EmployeeID:  1
# Max EmployeeID:  26849
# Employees ids not in the min-max range:  {14976, 22602, 26188, 1423, 4284}

# %% [markdown]
# We should check that all managers are also employees

# %%
managers = set(employees_df["Manager"])
employees = set(employees_df["EmployeeName"])

managers - employees
# Out:
# set()

# %% [markdown]
# Are these "missing employees" in other tables?

# %%
divisions_df[divisions_df["EmployeeID"].isin(missing_employees)]
# Out:
#        EmployeeID EmployeeName      Division  \
# 1422         1423          NaN  [Division 7]
# 4283         4284          NaN  [Division 7]
# 14975       14976          NaN  [Division 7]
# 22601       22602          NaN  [Division 7]
# 26187       26188          NaN  [Division 7]
#
#                                                  Project  \
# 1422                  [Project e-enable_holistic_models]
# 4283   [Project repurpose_collaborative_methodologies...
# 14975         [Project transform_24/365_functionalities]
# 22601  [Project monetize_one-to-one_mindshare, Projec...
# 26187               [Project extend_robust_action-items]
#
#               known_safehouses
# 1422       [14, 214, 181, 219]
# 4283                 [10, 219]
# 14975  [25, 154, 231, 33, 219]
# 22601   [12, 221, 19, 18, 219]
# 26187                 [7, 219]

# %% [markdown]
# What actions did they take?

# %%
actions_df[actions_df["EmployeeID"].isin(missing_employees)].sort_values("ActionDate")[
    "ActionDescription"
].values
# Out:
# array(['perform data mining on social media data for sentiment analysis through Advanced_coherent_architecture on Slovenia. Maintain strict confidentiality.',
#        'construct algorithms for automatic gait recognition through Phased_background_model on Guinea. Maintain strict confidentiality. During the covert operation, intercepted communications hinted at the presence of the three devices.',
#        'Initiate operation Networked_discrete_system_engine, targeting Yemen with objective to perform sentiment analysis on social media influencers In a confidential dossier, a defector mentioned the three devices being utilized to manipulate global financial markets.',
#        'Operation Re-contextualized_attitude-oriented_protocol to perform sentiment analysis on online news articles on North Macedonia is in progress. While examining classified documents, references to the three devices were discovered.',
#        "construct algorithms for automatic vein recognition through Upgradable_incremental_application on Saint Pierre and Miquelon. Maintain strict confidentiality. A smuggler's confession revealed their involvement in transporting the three devices across international borders.",
#        'Initiate operation Customizable_discrete_parallelism, targeting Costa Rica with objective to analyze temporal patterns in communication data',
#        'analyze communication patterns through Fully-configurable_6thgeneration_throughput on Chile. Maintain strict confidentiality. A recovered manuscript from an ancient civilization contained prophecies foretelling the rediscovery of the three devices in the modern era.',
#        'Operation Down-sized_24/7_capability to develop algorithms for automatic language translation on Argentina is in progress.',
#        'Initiate operation Centralized_upward-trending_concept, targeting Guinea with objective to develop algorithms for automatic language translation During an undercover operation, a suspect mentioned the existence of a secret society dedicated to harnessing the power of the three devices.',
#        "Operation Digitized_methodical_structure to apply statistical analysis to identify patterns in data on Malta is in progress. A smuggler's confession revealed their involvement in transporting the three devices across international borders.",
#        'Initiate operation Sharable_impactful_core, targeting Estonia with objective to develop algorithms for automatic target recognition Analysis of intercepted messages revealed a cryptic code mentioning the three devices.',
#        'analyze network topology for vulnerabilities through Enhanced_cohesive_application on Kuwait. Maintain strict confidentiality.',
#        "utilize machine learning for anomaly detection through Ameliorated_global_superstructure on Nepal. Maintain strict confidentiality. A decrypted audio recording captured a high-level conversation detailing the three devices' ability to manipulate spacetime.",
#        'perform text mining on classified documents through Multi-lateral_needs-based_Internet_solution on Aruba. Maintain strict confidentiality.',
#        'Initiate operation Digitized_dedicated_help-desk, targeting Bahamas with objective to create data-driven threat assessment models Analysis of surveillance footage identified an individual wearing a suspicious pendant believed to be related to the three devices.A reconnaissance team has been deployed around the Ecuador safehouse.',
#        'Operation Vision-oriented_explicit_flexibility to implement steganography techniques on Russian Federation is in progress. During the field investigation, a local informant reported sightings of individuals possessing the three devices.',
#        "Initiate operation Realigned_exuding_Graphic_Interface, targeting Barbados with objective to analyze network traffic for web application attacks An encrypted email chain revealed a covert organization's plan to unleash the power of the three devices for their own agenda.",
#        'Initiate operation Self-enabling_tangible_website, targeting Japan with objective to analyze temporal patterns in communication data Analysis of intercepted video footage revealed coded hand gestures used by a secret society to communicate about the three devices.'],
#       dtype=object)

# %% [markdown]
# They all mention the devices in their action description.

# %% [markdown]
# ## Safehouses

# %%
safehouses_df.sample(5)
# Out:
#       ID       City                                            Address  \
# 49   150     London  13 Graemesdyke Avenue, London, SW14 7BH, Unite...
# 181    8      Tokyo  34L-16R, Tokyo Wangan Road, Haneda Kukou, Ota,...
# 183    7      Paris  12 Rue Victor Hugo, 91390 Morsang-sur-Orge, Fr...
# 165   16     Moscow  улица Глинки 8, Firsanovka, Khimki, Moscow Obl...
# 84    83  Cartagena            Centro, 472000 Cartagena, BOL, Colombia
#
#       Latitude   Longitude
# 49   51.465893   -0.275055
# 181  35.556423  139.772161
# 183  48.664273    2.357661
# 165  55.948711   37.242120
# 84   10.428231  -75.570062

# %%
# Map of safehouses with Latitude and Longitude
import folium

safehouses_map = folium.Map(
    location=[safehouses_df["Latitude"].mean(), safehouses_df["Longitude"].mean()],
    zoom_start=4,
)

for index, row in safehouses_df.iterrows():
    folium.Marker([row["Latitude"], row["Longitude"]], popup=row["ID"]).add_to(
        safehouses_map
    )

safehouses_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9b707708195a814943a17aad872f524 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9b707708195a814943a17aad872f524&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9b707708195a814943a17aad872f524 = L.map(
#                 &quot;map_e9b707708195a814943a17aad872f524&quot;,
#                 {
#                     center: [19.47703134880941, 7.434807550788163],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2450ae52fc872772550f201f32bf91f1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9b707708195a814943a17aad872f524);
#
#
#             var marker_a903da3143094b146d8eefde7da74e21 = L.marker(
#                 [22.06871926, 95.9837443],
#                 {}
#             ).addTo(map_e9b707708195a814943a17aad872f524);
#
#
#         var popup_f4c557594ff32c7375fbddcc868f6668 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1ea879f9efedf1299e0cdd58d841a3c = $(`&lt;div id=&quot;html_c1ea879f9efedf1299e0cdd58d841a3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;233&lt;/div&gt;`)[0];
#                 popup_f4c557594ff32c7375fbddcc868f6668.setContent(html_c1ea879f9efedf1299e0cdd58d841a3c);
#
#
#
#         marker_a903da3143094b146d8eefde7da74e21.bindPopup(popup_f4c557594ff32c7375fbddcc868f6668)
#         ;
#
#
#
#
#             var marker_edd8a6deef6c59bb55a1a1d6a2ef06d5 = L.marker(
#                 [16.69945623, 96.35145029],
#                 {}
#             ).addTo(map_e9b707708195a814943a17aad872f524);
#
#
#         var popup_e408de2342cd648c007d0d9a341e8fb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2feab4006477f285e59511480ef02f24 = $(`&lt;div id=&quot;html_2feab4006477f285e59511480ef02f24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;232&lt;/div&gt;`)[0];
#                 popup_e408de2342cd648c007d0d9a341e8fb4.setContent(html_2feab4006477f285e59511480ef02f24);
#
#
#
#         marker_edd8a6deef6c59bb55a1a1d6a2ef06d5.bindPopup(popup_e408de2342cd648c007d0d9a341e8fb4)
#         ;
#
#
#
#
#             var marker_fc43f6306ab268bc13e804d010be76d6 = L.marker(
#                 [19.84308732, 102.159075],
#                 {}
#             ).addTo(map_e9b707708195a814943a17aad872f524);
#
#
#         var popup_01cd1a27398ff022d970c938afbd538b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fee44cdc4c72665ba56f0ad49dd68c81 = $(`&lt;div id=&quot;html_fee44cdc4c72665ba56f0ad49dd68c81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;231&lt;/div&gt;`)[0];
#                 popup_01cd1a27398ff022d970c938afbd538b.setContent(html_fee44cdc4c72665ba56f0ad49dd68c81);
#
#
#
#         marker_fc43f6306ab268bc13e804d010be76d6.bindPopup(popup_01cd1a27398ff022d970c938afbd538b)
#         ;
#
#
#
#
#             var marker_3d75755c80487b689cf7918770fbafcd = L.marker(
#                 [19.85258117, 102.1315775],
#                 {}
#             ).addTo(map_e9b707708195a814943a17aad872f524);
#
#
#         var popup_492baa1dcb69fd66511140d661b75956 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f58d31f072aacb07530010a0b932be03 = $(`&lt;div id=&quot;html_f58d31f072aacb07530010a0b932be03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;230&lt;/div&gt;`)[0];
#                 popup_492baa1dcb69fd66511140d661b75956.setContent(html_f58d31f072aacb07530010a0b932be03);
#
#
#
#         marker_3d75755c80487b689cf7918770fbafcd.bindPopup(popup_492baa1dcb69fd66511140d661b75956)
#         ;
#
#
#
#
#             var marker_d16b25475a2e7e38003dbdbb67f10100 = L.marker(
#                 [19.88750231, 102.1361868],
#                 {}
#             ).addTo(map_e9b707708195a814943a17aad872f524);
#
#
#         var popup_94dc12c64d15f9bca5837b8d7536a17d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c881d9740e6f6916e7a603020ea9bd63 = $(`&lt;div id=&quot;html_c881d9740e6f6916e7a603020ea9bd63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;229&lt;/div&gt;`)[0];
#                 popup_94dc12c64d15f9bca5837b8d7536a17d.setContent(html_c881d9740e6f6916e7a603020ea9bd63);
#
#
#
#         marker_d16b25475a2e7e38003dbdbb67f10100.bindPopup(popup_94dc12c64d15f9bca5837b8d7536a17d)
#         ;
#
#
#
#
#             var marker_08210e549b54aa8960aa431f6950e8a7 = L.marker(
#                 [17.89415493, 102.6896173],
#                 {}

# %% [markdown]
# Cute, but not very useful for now, let's move to divisions.

# %% [markdown]
# ## Divisions

# %%
divisions_df
# Out:
#        EmployeeID       EmployeeName                               Division  \
# 0               1         Kelly Rios                           [Division 1]
# 1               2       Madison Barr               [Division 6, Division 3]
# 2               3       Sue Anderson  [Division 5, Division 1, Division 10]
# 3               4      Laura Carlson   [Division 9, Division 9, Division 2]
# 4               5         Carrie Ali               [Division 3, Division 6]
# ...           ...                ...                                    ...
# 26844       26845  Christopher Riley  [Division 8, Division 10, Division 5]
# 26845       26846          Eric Chan   [Division 2, Division 6, Division 1]
# 26846       26847        Amy Vazquez  [Division 8, Division 10, Division 5]
# 26847       26848     Clifford Reyes   [Division 9, Division 2, Division 6]
# 26848       26849        Noah Snyder  [Division 2, Division 9, Division 10]
#
#                                                  Project   known_safehouses
# 0              [Project deliver_visionary_web-readiness]  [232, 1, 73, 217]
# 1        [Project repurpose_collaborative_methodologies]  [192, 26, 118, 4]
# 2        [Project repurpose_collaborative_methodologies]   [19, 8, 130, 50]
# 3               [Project streamline_proactive_e-markets]          [15, 232]
# 4              [Project deliver_visionary_web-readiness]         [158, 118]
# ...                                                  ...                ...
# 26844  [Project drive_value-added_mindshare, Project ...              [226]
# 26845          [Project deliver_visionary_web-readiness]       [15, 99, 58]
# 26846  [Project embrace_transparent_networks, Project...               [22]
# 26847  [Project disintermediate_distributed_experienc...               [98]
# 26848         [Project strategize_value-added_bandwidth]                [1]
#
# [26849 rows x 5 columns]

# %%
# TODO: Explode Division and Project

# %% [markdown]
# ### Managers

# %%
managers_df
# Out:
#            ManagerName         Employee_1         Employee_2  \
# 0          Raven Price       Carl Schmidt  Cristina Thompson
# 1          David Smith     Anthony Flores      John Trujillo
# 2     Michelle Frazier     Curtis Johnson    Michael Hancock
# 3       Melissa Conrad  Denise Gibson PhD       Christina Li
# 4         April Martin        Ryan Wright  Dr. Philip Jordan
# ...                ...                ...                ...
# 3830       Peter Burns    Kristin Ballard         Lisa Leach
# 3831  Randall Martinez        Maria Ortiz      George Graves
# 3832     Peter Jackson   Christopher Cook      Shannon Solis
# 3833      Susan Nguyen        Kevin Parks       James Holmes
# 3834       Mary Castro       Matthew Long       Joshua Jones
#
#                    Employee_3        Employee_4        Employee_5  \
# 0     Mrs. Katherine Franklin      Blake Garcia       Drew Berger
# 1              Elizabeth Page     William Hicks      Gail Salazar
# 2                  Renee Shaw        Lisa Lewis    Stephen Hunter
# 3               Rachel Snyder      James Taylor       Ivan Robles
# 4                  Gary Wolfe     Deborah Green               NaN
# ...                       ...               ...               ...
# 3830           Matthew Warner  Teresa Alexander      Robin Pierce
# 3831                Amy Baker       Deanna Cole  Samantha Collins
# 3832         Matthew Davidson    Lorraine Moore      Grant Garcia
# 3833            Danielle Long      Lynn Solomon     Justin Fisher
# 3834           Rachel Beasley    William Murphy      Sonya Knight
#
#            Employee_6          Employee_7     Employee_8           Employee_9  \
# 0         Dave Dennis      Gary Castaneda  Joan Crawford       Nicole Johnson
# 1      Linda Gonzalez  Christopher Miller    James Beard         Bradley Rowe
# 2                 NaN                 NaN            NaN                  NaN
# 3         Julie Adams      Michelle White            NaN                  NaN
# 4                 NaN                 NaN            NaN                  NaN
# ...               ...                 ...            ...                  ...
# 3830              NaN                 NaN            NaN                  NaN
# 3831  Melissa Aguilar      Michael Nguyen            NaN                  NaN
# 3832              NaN                 NaN            NaN                  NaN
# 3833      Sarah Moran                 NaN            NaN                  NaN
# 3834     Kenneth Yang          Alan Lopez  Heidi Collins  Jacqueline Robinson
#
#       ... Employee_20 Employee_21 Employee_22 Employee_23 Employee_24  \
# 0     ...         NaN         NaN         NaN         NaN         NaN
# 1     ...         NaN         NaN         NaN         NaN         NaN
# 2     ...         NaN         NaN         NaN         NaN         NaN
# 3     ...         NaN         NaN         NaN         NaN         NaN
# 4     ...         NaN         NaN         NaN         NaN         NaN
# ...   ...         ...         ...         ...         ...         ...
# 3830  ...         NaN         NaN         NaN         NaN         NaN
# 3831  ...         NaN         NaN         NaN         NaN         NaN
# 3832  ...         NaN         NaN         NaN         NaN         NaN
# 3833  ...         NaN         NaN         NaN         NaN         NaN
# 3834  ...         NaN         NaN         NaN         NaN         NaN
#
#      Employee_25 Employee_26 Employee_27 Employee_28 Employee_29
# 0            NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...
# 3830         NaN         NaN         NaN         NaN         NaN
# 3831         NaN         NaN         NaN         NaN         NaN
# 3832         NaN         NaN         NaN         NaN         NaN
# 3833         NaN         NaN         NaN         NaN         NaN
# 3834         NaN         NaN         NaN         NaN         NaN
#
# [3835 rows x 30 columns]

# %%
# Transform to long format
clean_managers_df = managers_df.melt(
    id_vars=["ManagerName"], value_name="Employee", var_name="EmployeeNumber"
)

# %%
clean_managers_df
# Out:
#              ManagerName EmployeeNumber           Employee
# 0            Raven Price     Employee_1       Carl Schmidt
# 1            David Smith     Employee_1     Anthony Flores
# 2       Michelle Frazier     Employee_1     Curtis Johnson
# 3         Melissa Conrad     Employee_1  Denise Gibson PhD
# 4           April Martin     Employee_1        Ryan Wright
# ...                  ...            ...                ...
# 111210       Peter Burns    Employee_29                NaN
# 111211  Randall Martinez    Employee_29                NaN
# 111212     Peter Jackson    Employee_29                NaN
# 111213      Susan Nguyen    Employee_29                NaN
# 111214       Mary Castro    Employee_29                NaN
#
# [111215 rows x 3 columns]

# %%
managers_df[managers_df["Employee_1"].isna()]
# Out:
#         ManagerName Employee_1 Employee_2 Employee_3 Employee_4 Employee_5  \
# 3686  Jessica Stone        NaN        NaN        NaN        NaN        NaN
#
#      Employee_6 Employee_7 Employee_8 Employee_9  ... Employee_20 Employee_21  \
# 3686        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#      Employee_22 Employee_23 Employee_24 Employee_25 Employee_26 Employee_27  \
# 3686         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Employee_28 Employee_29
# 3686         NaN         NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# Jessica Stone is the only manager without any employees (unless there are NaNs gaps).

# %%
clean_managers_df[clean_managers_df["Employee"] == "Jessica Stone"]
# Out:
#                 ManagerName EmployeeNumber       Employee
# 17210  Christopher Mckenzie     Employee_5  Jessica Stone

# %%
employees_df[employees_df["EmployeeName"] == "Jessica Stone"]
# Out:
#        EmployeeID   EmployeeName        JobTitle                    Email  \
# 11560       11563  Jessica Stone  Data Scientist  jessica_stone@brlda.gov
#
#                   Phone               Manager
# 11560  001-234-563-9331  Christopher Mckenzie

# %%
divisions_df[divisions_df["EmployeeName"] == "Jessica Stone"]
# Out:
#        EmployeeID   EmployeeName      Division  \
# 11562       11563  Jessica Stone  [Division 4]
#
#                                                  Project known_safehouses
# 11562  [Project mesh_cutting-edge_experiences, Projec...     [18, 42, 44]

# %%
clean_managers_df[clean_managers_df["Employee"] == "Christopher Mckenzie"]
# Out:
#       ManagerName EmployeeNumber              Employee
# 21390   Kayla Lee     Employee_6  Christopher Mckenzie

# %%
employees_df[employees_df["EmployeeName"] == "Christopher Mckenzie"]
# Out:
#        EmployeeID          EmployeeName          JobTitle  \
# 20679       20683  Christopher Mckenzie  Business Analyst
#
#                                 Email       Phone    Manager
# 20679  christopher_mckenzie@brlda.gov  3860450516  Kayla Lee
